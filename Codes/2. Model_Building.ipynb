# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# ## 1. Import Libraries

# %% [markdown]
# **Data Analysis and Visualization Setup with Python**
#
# **Description**
#
# This repository contains a Python script for setting up an environment for data analysis and visualization. It imports necessary libraries such as NumPy, Pandas, Matplotlib, and Seaborn. Additionally, it sets up configurations to ignore warnings during runtime.
#
# **Key Components**
#
# - **Libraries Used**:
#   - `NumPy`: For numerical computing with arrays and matrices.
#   - `Pandas`: For data manipulation and analysis.
#   - `Matplotlib`: For creating static, animated, and interactive visualizations.
#   - `Seaborn`: For statistical data visualization.
#
# - **Ignore Warnings**:
#   - Configuration to suppress warnings during runtime.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
import random
import os
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import callbacks
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Data Collection
#
# ### Surreal Symphonies - A Dataset of Diverse Art
#
# https://www.kaggle.com/datasets/cyanex1702/surreal-symphonies-a-dataset-of-diverse-art/data
#
# **Description**
#
# This dataset consists of a collection of 30 distinct artsy image folders, each showcasing its unique theme and style. The dataset contains a total of 7327 files with the following distribution based on file formats:
#
# - **.jpg**: 6821 files
# - **.png**: 304 files
# - **.jpeg**: 157 files
# - **Other formats(gif)**: 45 files
#
# You can use this dataset for various purposes, including art analysis, style transfer, and other creative and machine learning projects.

# %%
dataset_dir = '..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)'
dataset_dir = pathlib.Path(dataset_dir)

# %%
for dirname, _, filenames in os.walk(dataset_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\0e4pfg5n.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\0mrgszsi.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\0nv59gk5.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\0p5mr2u6.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\0tmfdsk7.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\104erwj8.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\10maslob.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\118oh5v1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\13g95g1j.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\156td6lk.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\16axam4y.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1baf5g21.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1e9x9gn7.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1exvjmgz.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1f8ap8o8.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1j8tg4ra.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1kr8uwkk.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1mvlwam8.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\1xqugbm0.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\28pe2lbf.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\2le48nqc.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\2o2zpob1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\2sv0kque.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\2ypilvcd.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3c35nxe8.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3gx0enc1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3hqryh9o.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3i22c1h4.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3isvwrdd.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3k9f6y51.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3vd70upc.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3yl9kjn0.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\3zvcbi7r.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\420onc0v.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\427eyxie.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\443rq9vt.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4759ngku.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4bcqx91r.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4dviwbz9.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4efccvqz.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4h1txyxz.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4l9zdlsg.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4p0no72n.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4ql0keae.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4twbsc8s.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\4ys9d5m5.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\5cv8pv0a.jpeg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\5t9drs9m.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\5zfkp7bu.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\5zv6a1ss.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\60uok8qk.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\68u1f4z1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\694l6dgn.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\6gk24odg.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\6ngjkxze.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\6wtmlk48.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\736p237k.jpeg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\73omlxhz.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7772sf7d.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7algbh17.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7av1p9bc.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7e3sz6jh.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7kviqovt.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7pccm4uu.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7vqsr4gi.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\7zmf6ypo.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\80rnakw1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\89fxdqxb.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8f0wkwsx.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8iyf0333.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8k2cmjei.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8kwq123u.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8mu74s6o.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8pnulsgw.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8uhi3er1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8upxaiuk.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\8zn3pl75.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\914q192u.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\9o0nfne3.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\9o5qtdra.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\9smejg51.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\9twdlxu9.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\a1vhq40e.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\a7ne2rbd.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\a7vg6ous.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\aa2e0zya.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\aem30jf5.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\aie34pwx.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\al19gc7a.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\aljsm2xr.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\am75p0la.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\atxbj4yj.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\b1j2e2ln.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\bafhgfpl.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\bipctx8p.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\bnbq1g58.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\bpvdxljq.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\bq1oteal.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\brtfqsin.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\bx6meq8p.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\c7xvt8bg.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\c8ewd0pn.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Abstract art\
.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\pd8am1s2.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\plhxeaja.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\pms9o1rd.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\q8vjvc77.JPG
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\qbfchva4.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\qdywzhql.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\qi5mnteo.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\qkvi33m6.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\qv95at58.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\qxnnilnj.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\r8p6pnmi.png
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\ro1e1n9m.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\s3s3sur9.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\s40apxjf.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\s88vpn2b.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\s9jrcoxk.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\sbgp2ks9.JPG
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\scxrh1nx.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\sfwnfmxp.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\sk48qf2h.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\srjf39hr.JPG
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\sxgp3oxj.png
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\szmkid9q.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\t0u9wukl.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\t1a05dhj.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\t82hkj3i.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\t8hi39oo.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\t8m0kh26.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\tjaizunc.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\tpvw3l03.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\u6g6efsu.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\ufbz3xj1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\uhjr64wz.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\uon3so8a.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\uxac2q20.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\v71mwp4j.JPG
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\vb0rhd6z.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\veqrp967.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\vk9eu0bq.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\vs3600u1.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\vtrj0ifl.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\vuqeuzgn.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\vvoor071.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\w39ree97.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\wj99lmb0.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\wrl6gipx.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\ww1zshb7.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\x4ureko6.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\xaaszr3a.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\xanh6n7t.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\xlxi9vp3.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\xsf4g4ph.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\y0nfbfdk.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\y17xf9s0.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\y8h2dxwg.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\yica7zfx.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\ytl0ozrb.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\yxdm2cys.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\yxlxgwl6.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\z3kzdyh4.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\zf69g15a.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\zhtgfr5h.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\znmnmykt.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\zoerml9f.jpg
# ..\Data\Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\Symbolism artwork\zro73467.jpg

# %% [markdown]
# ## 3. Data Exploration

# %% [markdown]
# **Image File Count Script**
#
# This script iterates through a dataset directory, counts the number of image files in each class subdirectory, and displays the results in a pandas DataFrame. It also calculates the total number of image files and the total number of classes.

# %%
# Dictionary to store the count of image files for each class
class_file_count = {}

# Variable to store the total number of image files
total_file_count = 0

# Iterate through the dataset directory to find all classes and count the number of image files
for main_dir in dataset_dir.iterdir():
    if main_dir.is_dir():
        for class_dir in main_dir.iterdir():
            if class_dir.is_dir():
                class_name = class_dir.name
                # Count the number of image files in this class subdirectory
                file_count = sum(1 for file in class_dir.glob(
                    '*') if file.suffix.lower() in ['.jpg', '.jpeg', '.png', '.jpe', '.gif'])
                class_file_count[class_name] = file_count
                total_file_count += file_count  # Add to the total number of files

# Number of classes
num_classes = len(class_file_count)

# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame(list(class_file_count.items()),
                  columns=['Class Name', 'File Count'])

# Add a row for the total number of files
# df.loc[''] = ['Total', total_file_count]

# Display the DataFrame
print(df)

# Display total number of classes and files separately
print(f"\nTotal number of classes: {num_classes}")
print(f"Total number of files: {total_file_count}")
# Out:
#                           Class Name  File Count
# 0                       Abstract art         283
# 1   Abstract expressionism paintings         253
# 2                       Academic art         220
# 3                 Art deco paintings         260
# 4              Art Nouveau paintings         254
# 5                  Baroque paintings         240
# 6                 Constructivism art         239
# 7                   Contemporary art         287
# 8                         Cubism art         290
# 9                    Dadaism artwork         259
# 10                       Digital art         279
# 11           Expressionism paintings         287
# 12                 Fauvism paintings         282
# 13                        Gothic art         291
# 14             Impressionism artwork         262
# 15               Mannerism paintings         226
# 16                    Minimalism art         260
# 17                 Modernism artwork          21
# 18                         Naive art         253
# 19             Neo-expressionism art         284
# 20                  Neoclassical art         277
# 21                           Pop art         261
# 22        Post-impressionism artwork         260
# 23          Pre-Raphaelite paintings          87
# 24                 Realism paintings         271
# 25             Renaissance paintings         283
# 26             Romanticism paintings         285
# 27                Surrealism artwork          18
# 28              Surrealist paintings         297
# 29                 Symbolism artwork         258
#
# Total number of classes: 30
# Total number of files: 7327

# %% [markdown]
# **File Extension Count Script**
#
# This script iterates through all files in a dataset directory, counts the number of files by their extension, and displays the results in a pandas DataFrame. It also calculates the total number of files.

# %%
# Dictionary to store the count of files by extension
total_files_by_extension = {}

# Iterate through all files in the dataset directory
for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        # Get the full path of the file
        file_path = os.path.join(root, file)
        # Get the file name and extension
        file_name, file_extension = os.path.splitext(file_path)
        # Add the file count to the dictionary based on its extension
        total_files_by_extension[file_extension.lower()] = total_files_by_extension.get(
            file_extension.lower(), 0) + 1

# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame(list(total_files_by_extension.items()),
                  columns=['Extension', 'File Count'])

# Calculate total number of files
total_files = df['File Count'].sum()

# Display the DataFrame
print(df)

# Display total number of files
print(f"\nTotal number of files: {total_files}")
# Out:
#   Extension  File Count
# 0      .jpg        6821
# 1     .jpeg         157
# 2      .jpe          12
# 3      .png         304
# 4      .gif          33
#
# Total number of files: 7327

# %% [markdown]
# **Duplicate File Name Detection Script**
#
# This script iterates through all files in a dataset directory, detects duplicate file names, and displays them. If no duplicates are found, it informs the user.

# %%
# List to store file names
all_file_names = []

# List to store duplicate file names
duplicate_file_names = []

# Iterate through all files in the dataset directory
for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        # Get the full path of the file
        file_path = os.path.join(root, file)
        # Get the file name
        file_name = pathlib.Path(file_path).name
        # Check if the file name is already in the list
        if file_name in all_file_names:
            duplicate_file_names.append(file_name)
        else:
            all_file_names.append(file_name)

# Display duplicate file names
if duplicate_file_names:
    print("Duplicate File Names:")
    for name in duplicate_file_names:
        print(name)
else:
    print("No duplicate file names found.")
# Out:
# No duplicate file names found.

# %% [markdown]
# **Dataset File Organization Script**
#
# This script organizes files from a dataset directory into a new directory structure. It creates the necessary subdirectories and copies files to their new locations while preserving the original directory hierarchy, excluding the top-level directory and the last directory segment.

# %%
# # Path ke direktori dataset
# inputs_dir = dataset_dir

# # Konversi ke objek Path
# inputs_dir = pathlib.Path(dataset_dir)

# # Direktori baru untuk menyimpan hasil modifikasi
# new_dataset_dir = '..\Data\Modified_Datasets'
# new_dataset_dir = pathlib.Path(new_dataset_dir)

# # Loop melalui semua file dalam direktori
# for dirname, _, filenames in os.walk(dataset_dir):
#     for filename in filenames:
#         # Dapatkan path lengkap ke file yang ada
#         file_path = os.path.join(dirname, filename)

#         # Bagi path menjadi bagian direktori dan nama file
#         dir_parts = dirname.split(os.sep)
#         # Mengambil semua bagian direktori kecuali yang terakhir dan "Datasets"
#         new_dirname = os.path.join(*dir_parts[1:-1])
#         new_filename = filename

#         # Buat folder baru jika belum ada di dalam direktori baru
#         new_dir_path = new_dataset_dir / new_dirname
#         new_dir_path.mkdir(parents=True, exist_ok=True)

#         # Path untuk file baru
#         new_file_path = new_dir_path / new_filename

#         # Copy file ke folder baru
#         os.system(f'copy "{file_path}" "{new_file_path}"')

#         # Cetak path file baru
#         print(new_file_path)

# %% [markdown]
# This script organizes files from a dataset directory into a new directory structure. It creates the necessary subdirectories and copies files to their new locations while preserving the original directory hierarchy, excluding the top-level directory and the last directory segment.

# %%
new_dataset_dir = '..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)'
new_dataset_dir = pathlib.Path(new_dataset_dir)

# %%
for dirname, _, filenames in os.walk(new_dataset_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\0e4pfg5n.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\0mrgszsi.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\0nv59gk5.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\0p5mr2u6.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\0tmfdsk7.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\104erwj8.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\10maslob.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\118oh5v1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\13g95g1j.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\156td6lk.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\16axam4y.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1baf5g21.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1e9x9gn7.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1exvjmgz.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1f8ap8o8.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1j8tg4ra.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1kr8uwkk.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1mvlwam8.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\1xqugbm0.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\28pe2lbf.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\2le48nqc.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\2o2zpob1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\2sv0kque.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\2ypilvcd.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3c35nxe8.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3gx0enc1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3hqryh9o.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3i22c1h4.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3isvwrdd.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3k9f6y51.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3vd70upc.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3yl9kjn0.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\3zvcbi7r.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\420onc0v.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\427eyxie.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\443rq9vt.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4759ngku.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4bcqx91r.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4dviwbz9.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4efccvqz.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4h1txyxz.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4l9zdlsg.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4p0no72n.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4ql0keae.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4twbsc8s.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\4ys9d5m5.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\5cv8pv0a.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\5t9drs9m.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\5zfkp7bu.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\5zv6a1ss.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\60uok8qk.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\68u1f4z1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\694l6dgn.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\6gk24odg.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\6ngjkxze.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\6wtmlk48.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\736p237k.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\73omlxhz.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7772sf7d.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7algbh17.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7av1p9bc.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7e3sz6jh.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7kviqovt.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7pccm4uu.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7vqsr4gi.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\7zmf6ypo.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\80rnakw1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\89fxdqxb.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8f0wkwsx.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8iyf0333.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8k2cmjei.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8kwq123u.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8mu74s6o.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8pnulsgw.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8uhi3er1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8upxaiuk.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\8zn3pl75.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\914q192u.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\9o0nfne3.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\9o5qtdra.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\9smejg51.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\9twdlxu9.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\a1vhq40e.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\a7ne2rbd.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\a7vg6ous.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\aa2e0zya.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\aem30jf5.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\aie34pwx.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\al19gc7a.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\aljsm2xr.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\am75p0la.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\atxbj4yj.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\b1j2e2ln.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\bafhgfpl.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\bipctx8p.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\bnbq1g58.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\bpvdxljq.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\bq1oteal.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\brtfqsin.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\bx6meq8p.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\c7xvt8bg.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\c8ewd0pn.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\cagosso5.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\cih1tn88.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\clfnupud.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\cmmx1ah7.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\cnenuv2w.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\cu0vyoeb.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\cv56yan4.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\d0pl351h.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\d1r28x3x.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\d2yy0gc9.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\d6dk6leb.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\daxjta71.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\db4bfpob.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\dhh4ypkg.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\dmpj3s3r.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\dxyi9071.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\e5xrgh3f.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\eb55fno1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\ecjczofv.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\efwo1kxw.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\eofr30fj.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\esnisa4o.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\ev4lvvm3.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\fchoy29v.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\fcw6xz9z.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\feszi8wr.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\fk9f3g8d.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\fkll9gvl.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\g6snvt1s.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\gbka34pc.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\gbti58rl.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\gefupf98.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\glqy3bem.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\gsh3p34a.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\gu35q0vh.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\gwqhnng7.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\h3n1eo1k.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\hafjnxb2.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\hn8zcwd7.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\hrp5lm9u.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\i209vxdl.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\i7ctgary.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\iaf4ou1p.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Image_217.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Image_249.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\Image_280.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art\iqkt3h2i.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Abstract art
png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\s88vpn2b.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\s9jrcoxk.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\sbgp2ks9.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\scxrh1nx.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\sfwnfmxp.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\sk48qf2h.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\srjf39hr.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\sxgp3oxj.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\szmkid9q.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\t0u9wukl.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\t1a05dhj.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\t82hkj3i.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\t8hi39oo.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\t8m0kh26.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\tjaizunc.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\tpvw3l03.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\u6g6efsu.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\ufbz3xj1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\uhjr64wz.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\uon3so8a.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\uxac2q20.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\v71mwp4j.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\vb0rhd6z.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\veqrp967.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\vk9eu0bq.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\vs3600u1.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\vtrj0ifl.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\vuqeuzgn.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\vvoor071.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\w39ree97.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\wj99lmb0.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\wrl6gipx.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\ww1zshb7.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\x4ureko6.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\xaaszr3a.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\xanh6n7t.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\xlxi9vp3.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\xsf4g4ph.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\y0nfbfdk.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\y17xf9s0.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\y8h2dxwg.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\yica7zfx.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\ytl0ozrb.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\yxdm2cys.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\yxlxgwl6.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\z3kzdyh4.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\zf69g15a.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\zhtgfr5h.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\znmnmykt.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\zoerml9f.png
# ..\Data\Modified_Datasets\Surreal Symphonies (A dataset of Diverse Artistic Visions)\Symbolism artwork\zro73467.png

# %% [markdown]
# **Dataset File Organization and Conversion to .png Script**
#
# This script organizes files from a dataset directory into a new directory structure, converts image files to PNG format, and replaces the original files. It creates the necessary subdirectories and copies files to their new locations while preserving the original directory hierarchy, excluding the top-level directory and the last directory segment.

# %%
# # Loop melalui semua file dalam direktori
# for root, dirs, files in os.walk(new_dataset_dir):
#     for file in files:
#         # Ambil path lengkap dari file
#         file_path = os.path.join(root, file)

#         # Pastikan file adalah gambar (anda bisa menyesuaikan dengan ekstensi yang diinginkan)
#         if file_path.lower().endswith(('.jpg', '.jpeg', '.jpe', '.gif')):
#             try:
#                 # Buka gambar
#                 with Image.open(file_path) as img:
#                     # Simpan gambar dalam format .png
#                     output_path = os.path.splitext(file_path)[0] + ".png"
#                     img.save(output_path, "PNG")

#                 # Hapus file asli
#                 os.remove(file_path)

#                 print(f"Converted and replaced {file_path} with {output_path}")

#             except Exception as e:
#                 print(f"Failed to convert {file_path}: {e}")

# print("Conversion completed.")

# %% [markdown]
# **File Extension Count After Convertinf to .png Script**
#
# This script iterates through all files in a dataset directory, counts the number of files by their extension, and displays the results in a pandas DataFrame. It also calculates the total number of files.

# %%
# Dictionary untuk menyimpan jumlah file dengan ekstensi yang sama
total_files_by_extension = {}

# Iterasi melalui semua file di dalam direktori dataset
for root, dirs, files in os.walk(new_dataset_dir):
    for file in files:
        # Ambil path lengkap dari file
        file_path = os.path.join(root, file)
        # Ambil nama file dan ekstensinya
        file_name, file_extension = os.path.splitext(file_path)
        # Tambahkan jumlah file ke dictionary berdasarkan ekstensinya
        total_files_by_extension[file_extension.lower()] = total_files_by_extension.get(
            file_extension.lower(), 0) + 1

# Cetak jumlah total file dengan ekstensi yang sama
print("Total files by extension:")
for ext, total in total_files_by_extension.items():
    print(f"{ext}: {total}")
# Out:
# Total files by extension:
# .png: 7327

# %% [markdown]
# **Dataset File Organization, Conversion, and Resizing Script**
#
# This script organizes files from a dataset directory into a new directory structure, converts image files to PNG format, resizes the images, and replaces the original files. It creates the necessary subdirectories and copies files to their new locations while preserving the original directory hierarchy, excluding the top-level directory and the last directory segment.

# %%
# # Ukuran baru
# new_size = (256, 256)

# # Loop melalui semua file dalam direktori
# for root, dirs, files in os.walk(new_dataset_dir):
#     for file in files:
#         # Ambil path lengkap dari file
#         file_path = os.path.join(root, file)

#         # Pastikan file adalah gambar (anda bisa menyesuaikan dengan ekstensi yang diinginkan)
#         if file_path.lower().endswith(('.jpg', '.jpeg', '.jpe', '.png', '.gif')):
#             try:
#                 # Buka gambar
#                 with Image.open(file_path) as img:
#                     # Resize gambar
#                     img_resized = img.resize(
#                         new_size, Image.Resampling.LANCZOS)

#                     # Simpan gambar yang telah diresize (mengganti file asli)
#                     img_resized.save(file_path)

#                     print(f"Resized {file_path}")

#             except Exception as e:
#                 print(f"Failed to process {file_path}: {e}")

# print("Resizing completed.")

# %% [markdown]
# ## 4. Data VIsualizations

# %% [markdown]
# **Sorting and Visualizing Class Counts**
#
# This script sorts the classes based on the number of image files and visualizes the distribution using a horizontal bar plot. It sorts the class counts in ascending order and assigns colors to classes based on their counts.

# %%
# Urutkan kelas berdasarkan jumlah file
sorted_class_counts = sorted(
    class_file_count.items(), key=lambda x: x[1], reverse=False)
sorted_class_names = [item[0] for item in sorted_class_counts]
sorted_file_counts = [item[1] for item in sorted_class_counts]

# Setel palet warna berdasarkan jumlah kelas
palette = sns.color_palette("plasma", len(sorted_class_counts))

# Creating a plot
plt.figure(figsize=(12, 8))
plt.barh(sorted_class_names, sorted_file_counts, color=palette)
plt.xlabel('Number of Image Files')
plt.ylabel('Class Name')
plt.title('Number of Image Files for Each Class in the Dataset')
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Displaying the plot
plt.show()

# %% [markdown]
# **Displaying Random Images from the Dataset**
#
# This script randomly selects images from the dataset and displays them in a grid layout. It allows you to specify the number of images (`n`) to display and sets the size of the images accordingly.

# %%
# Jumlah gambar yang ingin ditampilkan
n = 5

# Ukuran gambar
fig, axes = plt.subplots(1, n, figsize=(20, 10))

for i in range(n):
    # Pilih kelas secara acak
    random_class = random.choice(os.listdir(new_dataset_dir))
    class_dir = new_dataset_dir / random_class

    # Pilih gambar secara acak dari kelas yang dipilih
    random_image = random.choice(os.listdir(class_dir))
    random_image_file = class_dir / random_image

    # Baca dan tampilkan gambar
    image = plt.imread(random_image_file)
    axes[i].imshow(image)
    axes[i].set_title("Class: " + random_class +
                      "\n" + "Image: " + random_image)
    axes[i].axis('off')

# plt.savefig('demo.png', transparent=True)
plt.show()

# %% [markdown]
# # Model Building

# %%
# declare some variables
epochs = 100
batch_size = 32
img_height = 1080
img_width = 1620
resized_height = 512
resized_width = 512

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    new_dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    # image_size=(img_height, img_width),
    batch_size=batch_size)

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    new_dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    # image_size=(img_height, img_width),
    batch_size=batch_size)

# %%
class_names = train_ds.class_names
print(class_names)

# %%
plt.figure(figsize=(16, 16))

# Jumlah maksimum subplot yang bisa ditampilkan
max_subplots = 15

num_classes = min(len(class_names), max_subplots)

for i in range(num_classes):
    filtered_ds = train_ds.filter(lambda x, l: tf.math.equal(l[0], i))
    for image, label in filtered_ds.take(1):
        ax = plt.subplot(5, 5, i+1)
        plt.imshow(image[0].numpy().astype('uint8'))
        plt.title(class_names[label.numpy()[0]])
        plt.axis('off')

plt.tight_layout()
plt.show()
